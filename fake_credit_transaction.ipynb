# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv('original datasets/transactions/credit_risk.csv')

# %%
df.head(10)
# Out:
#    id  Duration in months                  Credit history  \
# 0   1                   6  critical/other existing credit
# 1   2                  48                   existing paid
# 2   3                  12  critical/other existing credit
# 3   4                  42                   existing paid
# 4   5                  24              delayed previously
# 5   6                  36                   existing paid
# 6   7                  24                   existing paid
# 7   8                  36                   existing paid
# 8   9                  12                   existing paid
# 9  10                  30  critical/other existing credit
#
#   Purpose of the credit  Credit amount Status of savings account/bonds  \
# 0              radio/tv           1169                no known savings
# 1              radio/tv           5951                            <100
# 2             education           2096                            <100
# ...

# %%
df.tail(10)
# Out:
#        id  Duration in months                  Credit history  \
# 990   991                  12  critical/other existing credit
# 991   992                  15                        all paid
# 992   993                  18                   existing paid
# 993   994                  36                   existing paid
# 994   995                  12                   existing paid
# 995   996                  12                   existing paid
# 996   997                  30                   existing paid
# 997   998                  12                   existing paid
# 998   999                  45                   existing paid
# 999  1000                  45  critical/other existing credit
#
#     Purpose of the credit  Credit amount Status of savings account/bonds  \
# 990             education           3565                no known savings
# 991              radio/tv           1569                      100<=X<500
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   id                                                        1000 non-null   int64
#  1   Duration in months                                        1000 non-null   int64
#  2   Credit history                                            1000 non-null   object
#  3   Purpose of the credit                                     1000 non-null   object
#  4   Credit amount                                             1000 non-null   int64
#  5   Status of savings account/bonds                           1000 non-null   object
#  6   Present employment(years)                                 1000 non-null   object
#  7   Installment rate in percentage of disposable income       1000 non-null   int64
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'Duration in months', 'Credit history', 'Purpose of the credit',
#        'Credit amount', 'Status of savings account/bonds',
#        'Present employment(years)',
#        'Installment rate in percentage of disposable income',
#        'personal_status', 'Other debtors / guarantors',
#        'Present residence since X years', 'Property', 'Age in years',
#        'Other installment plans (banks/stores)', 'Housing',
#        'Number of existing credits at this bank', 'Job',
#        'Number of people being liable to provide maintenance for', 'Telephone',
#        'Foreign worker', 'Status of existing checking account'],
#       dtype='object')

# %%
unique_durations = df["Duration in months"].unique()
print(unique_durations)
# Out:
# [ 6 48 12 42 24 36 30 15  9 10  7 60 18 45 11 27  8 54 20 14 33 21 16  4
#  47 13 22 39 28  5 26 72 40]

# %%
unique_credit_histories = df["Credit history"].unique()
print(unique_credit_histories)
# Out:
# ['critical/other existing credit' 'existing paid' 'delayed previously'
#  'no credits/all paid' 'all paid']

# %%
unique_purpose = df["Purpose of the credit"].unique()
print(unique_purpose)
# Out:
# ['radio/tv' 'education' 'furniture/equipment' 'new car' 'used car'
#  'business' 'domestic appliance' 'repairs' 'other' 'retraining']

# %%
credit_amount_min = df["Credit amount"].min()
print(credit_amount_min)
credit_amount_max = df["Credit amount"].max()
print(credit_amount_max)
# Out:
# 250
# 18424

# %%
unique_savings_status = df["Status of savings account/bonds"].unique()
print(unique_savings_status)
# Out:
# ['no known savings' '<100' '500<=X<1000' '>=1000' '100<=X<500']

# %%
unique_employment = df["Present employment(years)"].unique()
print(unique_employment)
# Out:
# ['>=7' '1<=X<4' '4<=X<7' 'unemployed' '<1']

# %%
# Tỷ lệ trả góp theo phần trăm của thu nhập khả dụng.
unique_installment_rate = df["Installment rate in percentage of disposable income"].unique()
print(unique_installment_rate)
# Out:
# [4 2 3 1]

# %%
unique_personal_status = df["personal_status"].unique()
print(unique_personal_status)
# Out:
# ['male single' 'female div/dep/mar' 'male div/sep' 'male mar/wid']

# %%
unique_debtors = df["Other debtors / guarantors"].unique()
print(unique_debtors)
# Out:
# ['none' 'guarantor' 'co applicant']

# %%
unique_residence_years = df["Present residence since X years"].unique()
print(unique_residence_years)
# Out:
# [4 2 3 1]

# %%
unique_property = df["Property"].unique()
print(unique_property)
# Out:
# ['real estate' 'life insurance' 'no known property' 'car']

# %%
min_age = df["Age in years"].min()
print('Min age: ', min_age)
max_age = df["Age in years"].max()
print('Max age: ', max_age)
# Out:
# Min age:  19
# Max age:  75

# %%
unique_installment_plans = df["Other installment plans (banks/stores)"].unique()
print(unique_installment_plans)
# Out:
# ['none' 'bank' 'stores']

# %%
unique_housing = df["Housing"].unique()
print(unique_housing)
# Out:
# ['own' 'for free' 'rent']

# %%
unique_credits_at_bank = df["Number of existing credits at this bank"].unique()
print(unique_credits_at_bank)
# Out:
# [2 1 3 4]

# %%
unique_job = df["Job"].unique()
print(unique_job)
# Out:
# ['skilled' 'unskilled resident' 'high qualif/self emp/mgmt'
#  'unemp/unskilled non res']

# %%
unique_maintenance_people = df["Number of people being liable to provide maintenance for"].unique()
print(unique_maintenance_people)
# Out:
# [1 2]

# %%
unique_telephone = df["Telephone"].unique()
print(unique_telephone)
# Out:
# ['yes' 'none']

# %%
unique_foreign_worker = df["Foreign worker"].unique()
print(unique_foreign_worker)
# Out:
# ['yes' 'no']

# %%
unique_checking_account_status = df["Status of existing checking account"].unique()
print(unique_checking_account_status)
# Out:
# ['good' 'bad']

# %%
    # numeric_df = df.select_dtypes(include=[float, int])
    # correlation_matrix = numeric_df.corr()

    # print(correlation_matrix)

    # plt.figure(figsize=(10, 8))
    # sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    # plt.title('Heatmap of Correlation Matrix')
    # plt.show()

# %%
new_records_credit_risk = pd.DataFrame()

new_records_credit_risk['id'] = range(1001, 2001)

for column in df.columns:
    if column != 'id':
        unique_values = df[column].unique()
        if len(unique_values) > 20:  
            min_value = df[column].min()
            max_value = df[column].max()
            new_records_credit_risk[column] = np.random.randint(min_value, max_value + 1, size=1000)
        else:
            new_records_credit_risk[column] = np.random.choice(unique_values, size=1000)

# %%
new_records_credit_risk.head(10)
# Out:
#      id  Duration in months                  Credit history  \
# 0  1001                  15              delayed previously
# 1  1002                  28                        all paid
# 2  1003                  32                        all paid
# 3  1004                  26  critical/other existing credit
# 4  1005                  45  critical/other existing credit
# 5  1006                  13  critical/other existing credit
# 6  1007                  24                        all paid
# 7  1008                  18                        all paid
# 8  1009                  38                   existing paid
# 9  1010                  45                        all paid
#
#   Purpose of the credit  Credit amount Status of savings account/bonds  \
# 0   furniture/equipment           8583                            <100
# 1              radio/tv           4580                          >=1000
# 2    domestic appliance           6575                          >=1000
# ...

# %%
new_records_credit_risk.to_csv('emulate data/transactions/credit_risk.csv', index=False)

# %% [markdown]
# ### 2nd dataset - bank churn
# **About this Dataset**
# The bank customer churn dataset is a commonly used dataset for predicting customer churn in the banking industry. It contains information on bank customers who either left the bank or continue to be a customer. The dataset includes the following attributes:
#
# - **Customer ID:** A unique identifier for each customer
# - **Surname:** The customer's surname or last name
# - **Credit Score:** A numerical value representing the customer's credit score
# - **Geography:** The country where the customer resides (France, Spain or Germany)
# - **Gender:** The customer's gender (Male or Female)
# - **Age:** The customer's age.
# - **Tenure:** The number of years the customer has been with the bank
# - **Balance:** The customer's account balance
# - **NumOfProducts:** The number of bank products the customer uses (e.g., savings account, credit card)
# - **HasCrCard:** Whether the customer has a credit card (1 = yes, 0 = no)
# - **IsActiveMember:** Whether the customer is an active member (1 = yes, 0 = no)
# - **EstimatedSalary:** The estimated salary of the customer
# - **Exited:** Whether the customer has churned (1 = yes, 0 = no)

# %%
df2 = pd.read_csv('original datasets/customers/Churn_Modelling.csv')

# %%
df2.info()
df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10001 non-null  int64
#  1   CustomerId       10001 non-null  int64
#  2   Surname          10001 non-null  object
#  3   CreditScore      10001 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10001 non-null  object
#  6   Age              10000 non-null  float64
#  7   Tenure           10001 non-null  int64
#  8   Balance          10001 non-null  float64
#  9   NumOfProducts    10001 non-null  int64
#  10  HasCrCard        10000 non-null  float64
#  11  IsActiveMember   10000 non-null  float64
#  12  EstimatedSalary  10001 non-null  float64
#  13  Exited           10001 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 1.1+ MB
# (10001, 14)

# %%
df2_sorted = df2.sort_values(by='CustomerId')
df2_sorted.head(5)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 1287       1288    15565701     Ferri          698     Spain  Female  39.0
# 4198       4199    15565706  Akobundu          612     Spain    Male  35.0
# 7090       7091    15565714  Cattaneo          601    France    Male  47.0
# 2020       2021    15565779      Kent          627   Germany  Female  30.0
# 3697       3698    15565796  Docherty          745   Germany    Male  48.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1287       9  161993.89              1        0.0             0.0
# 4198       1       0.00              1        1.0             1.0
# 7090       1   64430.06              2        0.0             1.0
# 2020       6   57809.32              1        1.0             0.0
# 3697      10   96048.55              1        1.0             0.0
#
#       EstimatedSalary  Exited
# 1287         90212.38       0
# 4198         83256.26       1
# ...

# %%
new_records_bank_customer_churn = pd.DataFrame()

new_records_bank_customer_churn['CustomerId'] = range(10001, 11001)

for column in df2.columns:
    if column not in ['CustomerId', 'RowNumber']:
        unique_values = df2[column].unique()
        if len(unique_values) > 10:
            if np.issubdtype(df2[column].dtype, np.number):
                min_value = df2[column].min()
                max_value = df2[column].max()
                new_records_bank_customer_churn[column] = np.random.randint(min_value, max_value + 1, size=1000)
            else:
                new_records_bank_customer_churn[column] = np.random.choice(unique_values, size=1000)
        else:
            new_records_bank_customer_churn[column] = np.random.choice(unique_values, size=1000)

# %%
new_records_bank_customer_churn.to_csv('emulate data/customers/new_records_bank_customer_churn.csv', index=False)

# %%
### 3rd dataset - bank marketing

# %%
df3 = pd.read_csv('original datasets/customers/bank-marketing.csv')

# %%
bank_marketing_unique_values = {col: df3[col].unique() for col in df3.columns}
num_records = 1000
data = {col: np.random.choice(bank_marketing_unique_values[col], num_records) for col in df3.columns}
df4 = pd.DataFrame(data)
df4.to_csv('emulate data/customers/new_records_bank-marketing.csv', index=False)
df4.head(10)
# Out:
#    age  age group eligible            job  salary   marital  education  \
# 0   34          5        N      housemaid    8000    single   tertiary
# 1   89          9        N         admin.   70000  divorced   tertiary
# 2   57          4        Y        student  120000  divorced   tertiary
# 3   67          6        Y        unknown    4000    single    primary
# 4   29          8        N  self-employed       0   married    unknown
# 5   54          7        Y     unemployed   50000  divorced   tertiary
# 6   37          8        N  self-employed    4000   married  secondary
# 7   35          9        N      housemaid  100000   married  secondary
# 8   23          1        Y         admin.   60000    single   tertiary
# 9   54          8        Y       services   70000    single  secondary
#
#     marital-education targeted default  ...    contact day month duration  \
# 0     married-primary      yes      no  ...    unknown  14   sep      924
# ...
